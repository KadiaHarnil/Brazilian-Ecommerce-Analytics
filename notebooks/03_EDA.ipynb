# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ## Objective
#
# The objective of this notebook is to explore the Brazilian E-Commerce dataset to understand customer behavior, order patterns, sales performance, seller activity, product trends, delivery efficiency, and payment preferences.
#
# The insights generated here will guide the business recommendations developed in later notebooks.

# %%
import pandas as pd

# %%
customers = pd.read_csv("../data/olist_customers_dataset.csv")
orders = pd.read_csv("../data/olist_orders_dataset.csv")
payments = pd.read_csv("../data/olist_order_payments_dataset.csv")
order_items = pd.read_csv("../data/olist_order_items_dataset.csv")
products = pd.read_csv("../data/olist_products_dataset.csv")
reviews = pd.read_csv("../data/olist_order_reviews_dataset.csv")
sellers = pd.read_csv("../data/olist_sellers_dataset.csv")
translation = pd.read_csv("../data/product_category_name_translation.csv")

# %%
customers.head()
customers.count()
# Out:
# customer_id                 99441
# customer_unique_id          99441
# customer_zip_code_prefix    99441
# customer_city               99441
# customer_state              99441
# dtype: int64
